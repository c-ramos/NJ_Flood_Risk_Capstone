# %%
# Join rainfall and njhomeprice tables from RDS
# Dependencies and Setup
#
import pandas as pd
import os
import datetime
import re
import numpy as np
import psycopg2
from sqlalchemy import create_engine

# %%
# Setup connection to Postgres RDS
engine = create_engine('postgresql+psycopg2://postgres:finalgroup5@finalprojectgroup5.c1jelrjhbrlm.us-east-1.rds.amazonaws.com:5432/postgres')

# %%
# Join rainfall and njhomeprice
query = ("SELECT * from njhomeprice"
     )
#new_df = pysqldf("SELECT a.*, b.list3 from df1 as a INNER JOIN df2 as b ON a.key=b.key;")
njhomeprice_df=pd.read_sql(query,engine)

# %%
njhomeprice_df
# Out:
#          index zipcode State                  CITY         CountyName  \
# 0            0   08701    NJ     Lakewood Township       Ocean County
# 1            1   08753    NJ            Toms River       Ocean County
# 2            2   07002    NJ               Bayonne      Hudson County
# 3            3   07087    NJ            Union City      Hudson County
# 4            4   08759    NJ   Manchester Township       Ocean County
# ...        ...     ...   ...                   ...                ...
# 124811  124811   08555    NJ             Roosevelt    Monmouth County
# 124812  124812   08323    NJ    Greenwich Township  Cumberland County
# 124813  124813   08350    NJ  Buena Vista Township    Atlantic County
# 124814  124814   08346    NJ  Buena Vista Township    Atlantic County
# 124815  124815   08212    NJ        Cape May Point    Cape May County
#
#         SizeRank   eom_date  month  year  avghomeprice_month price_drop
# ...
